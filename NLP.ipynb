# %% [markdown]
# # NATURAL LANGUAGE PROCESSING

# %%
from nltk.corpus import brown
brown.words()
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
from nltk.book import *
from nltk.corpus import brown
brown.categories()
reviews_words=brown.words(categories='reviews')
reviews_words
len(reviews_words)
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# 40704

# %% [markdown]
# # STOPWORDS

# %%
from nltk.corpus import stopwords
set(stopwords.words('english'))
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

example_sent="an Apple a day keeps diseases at bay."

stopwords=set(stopwords.words('english'))
words_tokens=word_tokenize(example_sent)

filtered_sentence=[w for w in words_tokens if not w in stopwords]
filtered_sentence=[]

for w in words_tokens:
    if w not in stopwords:
        filtered_sentence.append(w)
        
print(filtered_sentence)
# Out:
# ['Apple', 'day', 'keeps', 'diseases', 'bay', '.']

# %%
from nltk.corpus import stopwords
set(stopwords.words('french'))
# Out:
# {'ai',
#  'aie',
#  'aient',
#  'aies',
#  'ait',
#  'as',
#  'au',
#  'aura',
#  'aurai',
#  'auraient',
#  'aurais',
#  'aurait',
#  'auras',
#  'aurez',
#  'auriez',
#  'aurions',
#  'aurons',
#  'auront',
#  'aux',
#  'avaient',
#  'avais',
#  'avait',
#  'avec',
#  'avez',
#  'aviez',
#  'avions',
#  'avons',
#  'ayant',
#  'ayante',
#  'ayantes',
#  'ayants',
#  'ayez',
#  'ayons',
#  'c',
#  'ce',
#  'ces',
#  'd',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'es',
#  'est',
#  'et',
#  'eu',
#  'eue',
#  'eues',
#  'eurent',
#  'eus',
#  'eusse',
#  'eussent',
#  'eusses',
#  'eussiez',
#  'eussions',
#  'eut',
#  'eux',
#  'eûmes',
#  'eût',
#  'eûtes',
#  'furent',
#  'fus',
#  'fusse',
#  'fussent',
#  'fusses',
#  'fussiez',
#  'fussions',
#  'fut',
#  'fûmes',
#  'fût',
#  'fûtes',
#  'il',
#  'ils',
#  'j',
#  'je',
#  'l',
#  'la',
#  'le',
#  'les',
#  'leur',
#  'lui',
#  'm',
#  'ma',
#  'mais',
#  'me',
#  'mes',
#  'moi',
#  'mon',
#  'même',
# ...

# %% [markdown]
# # STEMMING
# Stemming involves reducing a word to stem or base(root) form by removing suffixes.
# Various stemming algorithms: Porter stemmer,Lancaster stemmer,Snowball stemmer

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize,word_tokenize
ps=PorterStemmer()
new_text= "importance of caving as explained by cavers"

words = word_tokenize(new_text)
for w in words:
    print(ps.stem(w))
# Out:
# import
# of
# cave
# as
# explain
# by
# caver

# %% [markdown]
# # Lemmatization
# This is he method of grouping the various inflected types of a word so that they can be analyzed as one item.
# It uses a vocabulary list and morphological analysis(POS of a word) to get the root word.

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize('feet'))
print(lemmatizer.lemmatize('cacti'))
print(lemmatizer.lemmatize('geese'))

#without a POS tag,lemmatizer assumes everything in a noun
print(lemmatizer.lemmatize('loving'))
print(lemmatizer.lemmatize('loving','v'))
# Out:
# foot
# cactus
# goose
# loving
# love

# %% [markdown]
# # POS Tagging
# Part-Of-Speech tagging marks words in the corpus to a correspponding part of speech tag based on its context and definition
# POS tags are used in text analysis tools and in corpus searches

# %%
import nltk
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
txt='''Text Mining also referred to as text data mining,
roughly equivalent to text analytics, is te process of deriving high quality information from text.
High quality information is typically derived through the deriving of patterns and trends through means such as statistical pattern learning.'''
tokenized=sent_tokenize(txt)
for i in tokenized:
    wordsList = nltk.word_tokenize(i)
    wordsList= [w for w in wordsList if not w in stop_words]
    tagged=nltk.pos_tag(wordsList)
    
tagged
# Out:
# [('High', 'JJ'),
#  ('quality', 'NN'),
#  ('information', 'NN'),
#  ('typically', 'RB'),
#  ('derived', 'VBD'),
#  ('deriving', 'VBG'),
#  ('patterns', 'NNS'),
#  ('trends', 'NNS'),
#  ('means', 'VBZ'),
#  ('statistical', 'JJ'),
#  ('pattern', 'NN'),
#  ('learning', 'NN'),
#  ('.', '.')]

# %% [markdown]
# POS Tags are useful for lemmatization, in building NERs and extracting relationships between words

# %% [markdown]
# # Named Entity Recognition(NER)
# NER seeks to extract a real world entity from the text and sorts it into predefined categories such as the names of persons, organizations,locations,etc...

# %%
import nltk
doc='''Twitter's origins lie in a "daylong brainstorming session" held by board members of the podcasting company Odeo. Jack Dorsey, then an undergraduate student at New York University, introduced the idea of an individual using an SMS service to communicate with a small group.[34][35] The original project code name for the service was twttr, an idea that Williams later ascribed to Noah Glass,[36] inspired by Flickr and the five-character length of American SMS short codes. The decision was also partly due to the fact that the domain twitter.com was already in use, and it was six months after the launch of twttr that the crew purchased the domain and changed the name of the service to Twitter.[37] '''
#tokensize doc
tokenized_doc=nltk.word_tokenize(doc)
tagged_sentences=nltk.pos_tag(tokenized_doc)
ne_chunked_sents=nltk.ne_chunk(tagged_sentences)

#extract all named entities
named_entities=[]
for tagged_tree in ne_chunked_sents:
    if hasattr(tagged_tree,'label'):
        entity_name=' '.join(c[0] for c in tagged_tree.leaves())
        entity_type=tagged_tree.label()
        named_entities.append((entity_name,entity_type))
print(named_entities)
# Out:
# [('Twitter', 'PERSON'), ('Odeo', 'PERSON'), ('Jack Dorsey', 'PERSON'), ('New York University', 'GPE'), ('SMS', 'ORGANIZATION'), ('Williams', 'PERSON'), ('Noah Glass', 'PERSON'), ('Flickr', 'PERSON'), ('American', 'GPE'), ('SMS', 'ORGANIZATION'), ('Twitter', 'PERSON')]

# %% [markdown]
# # Demo Brown Corpus

# %%
import nltk
from nltk.corpus import brown

# %%
with open('bbtext.txt','r')as myfile:
    data=myfile.read().replace('\n','')

# %%
data2=data.replace("/","")

# %%
for i, line in enumerate(data.split('\n')):
    if i>10:
        break
    print(str(i)+':\t'+line)
# Out:
# 0:	Email No.,the,to,ect,and,for,of,a,you,hou,in,on,is,this,enron,i,be,that,will,have,with,your,at,we,s,are,it,by,com,as,from,gas,or,not,me,deal,if,meter,hpl,please,re,e,any,our,corp,can,d,all,has,was,know,need,an,forwarded,new,t,may,up,j,mmbtu,should,do,am,get,out,see,no,there,price,daren,but,been,company,l,these,let,so,would,m,into,xls,farmer,attached,us,information,they,message,day,time,my,one,what,only,http,th,volume,mail,contract,which,month,more,robert,sitara,about,texas,nom,energy,pec,questions,www,deals,volumes,pm,ena,now,their,file,some,email,just,also,call,change,other,here,like,b,flow,net,following,p,production,when,over,back,want,original,them,below,o,ticket,c,he,could,make,inc,report,march,contact,were,days,list,nomination,system,who,april,number,sale,don,its,first,thanks,business,help,per,through,july,forward,font,free,daily,use,order,today,r,had,fw,set,plant,statements,go,gary,oil,line,sales,w,effective,well,tenaska,take,june,x,within,nbsp,she,how,north,america,being,un
# ...

# %%
from nltk import sent_tokenize,word_tokenize

# %%
sent_tokenize(data2)
# Out:
# ['Email No.,the,to,ect,and,for,of,a,you,hou,in,on,is,this,enron,i,be,that,will,have,with,your,at,we,s,are,it,by,com,as,from,gas,or,not,me,deal,if,meter,hpl,please,re,e,any,our,corp,can,d,all,has,was,know,need,an,forwarded,new,t,may,up,j,mmbtu,should,do,am,get,out,see,no,there,price,daren,but,been,company,l,these,let,so,would,m,into,xls,farmer,attached,us,information,they,message,day,time,my,one,what,only,http,th,volume,mail,contract,which,month,more,robert,sitara,about,texas,nom,energy,pec,questions,www,deals,volumes,pm,ena,now,their,file,some,email,just,also,call,change,other,here,like,b,flow,net,following,p,production,when,over,back,want,original,them,below,o,ticket,c,he,could,make,inc,report,march,contact,were,days,list,nomination,system,who,april,number,sale,don,its,first,thanks,business,help,per,through,july,forward,font,free,daily,use,order,today,r,had,fw,set,plant,statements,go,gary,oil,line,sales,w,effective,well,tenaska,take,june,x,within,nbsp,she,how,north,america,being,und
# ...

# %%
for sent in sent_tokenize(data2):
    print(word_tokenize(sent))
# Out:
# ['Email', 'No.', ',', 'the', ',', 'to', ',', 'ect', ',', 'and', ',', 'for', ',', 'of', ',', 'a', ',', 'you', ',', 'hou', ',', 'in', ',', 'on', ',', 'is', ',', 'this', ',', 'enron', ',', 'i', ',', 'be', ',', 'that', ',', 'will', ',', 'have', ',', 'with', ',', 'your', ',', 'at', ',', 'we', ',', 's', ',', 'are', ',', 'it', ',', 'by', ',', 'com', ',', 'as', ',', 'from', ',', 'gas', ',', 'or', ',', 'not', ',', 'me', ',', 'deal', ',', 'if', ',', 'meter', ',', 'hpl', ',', 'please', ',', 're', ',', 'e', ',', 'any', ',', 'our', ',', 'corp', ',', 'can', ',', 'd', ',', 'all', ',', 'has', ',', 'was', ',', 'know', ',', 'need', ',', 'an', ',', 'forwarded', ',', 'new', ',', 't', ',', 'may', ',', 'up', ',', 'j', ',', 'mmbtu', ',', 'should', ',', 'do', ',', 'am', ',', 'get', ',', 'out', ',', 'see', ',', 'no', ',', 'there', ',', 'price', ',', 'daren', ',', 'but', ',', 'been', ',', 'company', ',', 'l', ',', 'these', ',', 'let', ',', 'so', ',', 'would', ',', 'm', ',', 'into', ',', 'xls', ',', 'farmer', 
# ...

# %%
from nltk.corpus import stopwords
stpowords_en=stopwords.words('english')

# %%
single_tokenized_lowered=list(map(str.lower,word_tokenize(data2)))
print(single_tokenized_lowered)
# Out:
# ['email', 'no.', ',', 'the', ',', 'to', ',', 'ect', ',', 'and', ',', 'for', ',', 'of', ',', 'a', ',', 'you', ',', 'hou', ',', 'in', ',', 'on', ',', 'is', ',', 'this', ',', 'enron', ',', 'i', ',', 'be', ',', 'that', ',', 'will', ',', 'have', ',', 'with', ',', 'your', ',', 'at', ',', 'we', ',', 's', ',', 'are', ',', 'it', ',', 'by', ',', 'com', ',', 'as', ',', 'from', ',', 'gas', ',', 'or', ',', 'not', ',', 'me', ',', 'deal', ',', 'if', ',', 'meter', ',', 'hpl', ',', 'please', ',', 're', ',', 'e', ',', 'any', ',', 'our', ',', 'corp', ',', 'can', ',', 'd', ',', 'all', ',', 'has', ',', 'was', ',', 'know', ',', 'need', ',', 'an', ',', 'forwarded', ',', 'new', ',', 't', ',', 'may', ',', 'up', ',', 'j', ',', 'mmbtu', ',', 'should', ',', 'do', ',', 'am', ',', 'get', ',', 'out', ',', 'see', ',', 'no', ',', 'there', ',', 'price', ',', 'daren', ',', 'but', ',', 'been', ',', 'company', ',', 'l', ',', 'these', ',', 'let', ',', 'so', ',', 'would', ',', 'm', ',', 'into', ',', 'xls', ',', 'farmer', 
# ...

# %%
stopwords_en=set(stopwords.words('english'))
print([word for word in single_tokenized_lowered if word not in stopwords_en])
# Out:
# ['email', 'no.', ',', ',', ',', 'ect', ',', ',', ',', ',', ',', ',', 'hou', ',', ',', ',', ',', ',', 'enron', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'com', ',', ',', ',', 'gas', ',', ',', ',', ',', 'deal', ',', ',', 'meter', ',', 'hpl', ',', 'please', ',', ',', 'e', ',', ',', ',', 'corp', ',', ',', ',', ',', ',', ',', 'know', ',', 'need', ',', ',', 'forwarded', ',', 'new', ',', ',', 'may', ',', ',', 'j', ',', 'mmbtu', ',', ',', ',', ',', 'get', ',', ',', 'see', ',', ',', ',', 'price', ',', 'daren', ',', ',', ',', 'company', ',', 'l', ',', ',', 'let', ',', ',', 'would', ',', ',', ',', 'xls', ',', 'farmer', ',', 'attached', ',', 'us', ',', 'information', ',', ',', 'message', ',', 'day', ',', 'time', ',', ',', 'one', ',', ',', ',', 'http', ',', 'th', ',', 'volume', ',', 'mail', ',', 'contract', ',', ',', 'month', ',', ',', 'robert', ',', 'sitara', ',', ',', 'texas', ',', 'nom', ',', 'energy', ',', 'pec', ',', 'questions', ',', 'www', ',', 'deals', ',', 'vo
# ...

# %%
from string import punctuation
print('From string.punctuation: ',type(punctuation),punctuation)
# Out:
# From string.punctuation:  <class 'str'> !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
stopwords_en_withpunct=stopwords_en.union(set(punctuation))
print(stopwords_en_withpunct)
# Out:
# {'if', 'yours', "mightn't", 'our', "you'll", 'now', 'himself', "don't", 'as', 'each', 'being', 'while', 'he', '_', 'have', '*', 'your', 'up', 'an', "shouldn't", "won't", 'over', ']', "doesn't", 'aren', 'myself', 'shouldn', 'on', 'weren', 'there', 's', "you've", 'my', 'other', 'because', '.', '"', 'those', 'all', 'didn', "that'll", '(', 'doesn', 'we', 'be', 'its', 'ours', 'yourself', 'same', '\\', 'did', 'whom', "you'd", 'any', "couldn't", 'him', 'are', 'through', 'am', "wouldn't", 'into', "aren't", 'own', 'doing', 've', "should've", "hadn't", 'by', 'in', "mustn't", 'has', 'how', 'both', 'is', '^', 'needn', 'before', 'such', 'can', 'no', ')', 'or', 'o', 'so', 'she', 'this', 'further', 'only', "weren't", 'most', 'mightn', 'their', 'what', 'when', 'off', "shan't", '[', "needn't", '=', '#', 'mustn', "haven't", 'having', ',', 'wasn', '<', '~', '%', 'been', 'below', ':', '@', 'above', '|', 'ourselves', 'just', 'them', 'too', 'hadn', "wasn't", 'wouldn', '`', "didn't", '+', 're', 'will', 'a'
# ...

# %%
print([word for word in single_tokenized_lowered if word not in stopwords_en_withpunct])
# Out:
# ['email', 'no.', 'ect', 'hou', 'enron', 'com', 'gas', 'deal', 'meter', 'hpl', 'please', 'e', 'corp', 'know', 'need', 'forwarded', 'new', 'may', 'j', 'mmbtu', 'get', 'see', 'price', 'daren', 'company', 'l', 'let', 'would', 'xls', 'farmer', 'attached', 'us', 'information', 'message', 'day', 'time', 'one', 'http', 'th', 'volume', 'mail', 'contract', 'month', 'robert', 'sitara', 'texas', 'nom', 'energy', 'pec', 'questions', 'www', 'deals', 'volumes', 'pm', 'ena', 'file', 'email', 'also', 'call', 'change', 'like', 'b', 'flow', 'net', 'following', 'p', 'production', 'back', 'want', 'original', 'ticket', 'c', 'could', 'make', 'inc', 'report', 'march', 'contact', 'days', 'list', 'nomination', 'system', 'april', 'number', 'sale', 'first', 'thanks', 'business', 'help', 'per', 'july', 'forward', 'font', 'free', 'daily', 'use', 'order', 'today', 'r', 'fw', 'set', 'plant', 'statements', 'go', 'gary', 'oil', 'line', 'sales', 'w', 'effective', 'well', 'tenaska', 'take', 'june', 'x', 'within', 'nbsp
# ...

# %%
from nltk.stem import PorterStemmer
porter=PorterStemmer()

for word in single_tokenized_lowered:
    print(porter.stem(word))
# Out:
# email
# no.
# ,
# the
# ,
# to
# ,
# ect
# ,
# and
# ,
# for
# ,
# of
# ,
# a
# ,
# you
# ,
# hou
# ,
# in
# ,
# on
# ,
# is
# ,
# thi
# ,
# enron
# ,
# i
# ,
# be
# ,
# that
# ,
# will
# ,
# have
# ,
# with
# ,
# your
# ,
# at
# ,
# we
# ,
# s
# ,
# are
# ,
# it
# ,
# by
# ,
# com
# ,
# as
# ,
# from
# ,
# ga
# ,
# or
# ,
# not
# ,
# me
# ,
# deal
# ,
# if
# ,
# meter
# ,
# hpl
# ,
# pleas
# ,
# re
# ,
# e
# ,
# ani
# ,
# our
# ,
# corp
# ,
# can
# ,
# d
# ,
# all
# ,
# ha
# ,
# wa
# ,
# know
# ,
# need
# ,
# an
# ,
# forward
# ,
# new
# ,
# t
# ,
# may
# ,
# up
# ,
# j
# ,
# mmbtu
# ,
# should
# ,
# do
# ,
# am
# ,
# get
# ,
# out
# ,
# see
# ,
# no
# ,
# there
# ,
# price
# ,
# daren
# ,
# but
# ,
# been
# ,
# compani
# ,
# l
# ,
# these
# ,
# let
# ,
# so
# ,
# would
# ,
# m
# ,
# into
# ,
# xl
# ,
# farmer
# ,
# attach
# ,
# us
# ,
# inform
# ,
# they
# ,
# messag
# ,
# day
# ,
# time
# ,
# my
# ,
# one
# ,
# what
# ,
# onli
# ,
# http
# ,
# th
# ,
# volum
# ,
# mail
# ,
# ...

# %%
from nltk.stem import WordNetLemmatizer
wnl=WordNetLemmatizer()

# %%
for word in single_tokenized_lowered:
    print(wnl.lemmatize(word))
# Out:
# email
# no.
# ,
# the
# ,
# to
# ,
# ect
# ,
# and
# ,
# for
# ,
# of
# ,
# a
# ,
# you
# ,
# hou
# ,
# in
# ,
# on
# ,
# is
# ,
# this
# ,
# enron
# ,
# i
# ,
# be
# ,
# that
# ,
# will
# ,
# have
# ,
# with
# ,
# your
# ,
# at
# ,
# we
# ,
# s
# ,
# are
# ,
# it
# ,
# by
# ,
# com
# ,
# a
# ,
# from
# ,
# gas
# ,
# or
# ,
# not
# ,
# me
# ,
# deal
# ,
# if
# ,
# meter
# ,
# hpl
# ,
# please
# ,
# re
# ,
# e
# ,
# any
# ,
# our
# ,
# corp
# ,
# can
# ,
# d
# ,
# all
# ,
# ha
# ,
# wa
# ,
# know
# ,
# need
# ,
# an
# ,
# forwarded
# ,
# new
# ,
# t
# ,
# may
# ,
# up
# ,
# j
# ,
# mmbtu
# ,
# should
# ,
# do
# ,
# am
# ,
# get
# ,
# out
# ,
# see
# ,
# no
# ,
# there
# ,
# price
# ,
# daren
# ,
# but
# ,
# been
# ,
# company
# ,
# l
# ,
# these
# ,
# let
# ,
# so
# ,
# would
# ,
# m
# ,
# into
# ,
# xl
# ,
# farmer
# ,
# attached
# ,
# u
# ,
# information
# ,
# they
# ,
# message
# ,
# day
# ,
# time
# ,
# my
# ,
# one
# ,
# what
# ,
# only
# ,
# http
# ,
# th
# ,
# volume
# ,
# ...

# %%
stop_words = set(stopwords.words('english'))
tokenized=sent_tokenize(data2)
for i in tokenized:
    wordslist= nltk.word_tokenize(i)
    wordslist=[w for w in wordslist if not w in stop_words]
    tagged=nltk.pos_tag(wordslist)
    
    print(tagged)
# Out:
# [('Email', 'NNP'), ('No.', 'NN'), (',', ','), (',', ','), (',', ','), ('ect', 'NN'), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), ('hou', 'NN'), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), ('enron', 'NN'), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), ('com', 'NN'), (',', ','), (',', ','), (',', ','), ('gas', 'NN'), (',', ','), (',', ','), (',', ','), (',', ','), ('deal', 'NN'), (',', ','), (',', ','), ('meter', 'NN'), (',', ','), ('hpl', 'NN'), (',', ','), ('please', 'NN'), (',', ','), (',', ','), ('e', 'NN'), (',', ','), (',', ','), (',', ','), ('corp', 'NN'), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), (',', ','), ('know', 'VBP'), (',', ','), ('need', 'VBP'), (',', ','), (',', ','), ('forwarded', 'VBD'), (',', ','), ('new', 'JJ'), (',', ','), (',', ','), ('may', 'MD'), (',', ','), (',', ','), ('j', 'NN'
# ...

# %%
sentences=nltk.sent_tokenize(data2)
tokenized_sentences=[nltk.word_tokenize(sentence) for sentence in sentences]
tagged_sentences=[nltk.pos_tag(sentence)for sentence in tokenized_sentences]
chunked_sentences= nltk.ne_chunk_sents(tagged_sentences,binary=True)
                    
def extract_entity_names(t):
    entity_names=[]
    
    if hasattr(t,'label')and t.label:
        if(t.label()=='NE'):
            entity_names.append(' '.join([child[0] for child in t]))
        else:
            for child in t:
                entity_names.extend(extract_entity_names(child))
    return entity_names
entity_names=[]
for tree in chunked_sentences:
           entity_names.extend(extract_entity_names(tree))
print(set(entity_names))
# Out:
# {'Email'}

# %% [markdown]
# # Structuring Sentences and CFG

# %% [markdown]
# # Syntax
# Syntax is the grammatcal structure of sentences.

# %%
import os
path_to_gs="C:\Users\ADMIN\Downloads\gs10012w64.exe"
os.environ['PATH']+=os.pathsep+path_to_gs
# Out:
#   Cell In[29], line 2
#     path_to_gs="C:\Users\ADMIN\Downloads\gs10012w64.exe"
#                                                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# # Chunking Using Python

# %%
sent="The little moouse ate the fresh cheese"
sent_tokens=nltk.pos_tag(word_tokenize(sent))
sent_tokens
# Out:
# [('The', 'DT'),
#  ('little', 'JJ'),
#  ('moouse', 'NN'),
#  ('ate', 'VB'),
#  ('the', 'DT'),
#  ('fresh', 'JJ'),
#  ('cheese', 'NN')]

# %% [markdown]
# You will now create grammer from a noun phrase and will mention the tags you want in your chunk phrase with in {}

# %%
grammer_np=r"NP:{<DT>?<JJ>*<NN>}"
chunk_parser=nltk.RegexpParser(grammer_np)

# %%
chunk_result=chunk_parser.parse(sent_tokens)
print(chunk_result)
# Out:
# (S
#   (NP The/DT little/JJ moouse/NN)
#   ate/VB
#   (NP the/DT fresh/JJ cheese/NN))

# %% [markdown]
# Create a verb phrase chunk using regular expressions

# %%
grammer_vp=r"vp:{<PRP>?<VB|VBD|VBZ|CBG>*<RB|RBR>?}"

# %%
chunk_parser2=nltk.RegexpParser(grammer_vp)

# %%
sent3="She is walking quickly to the mall"
sent_tokens3=nltk.pos_tag(word_tokenize(sent))
sent_tokens3
# Out:
# [('The', 'DT'),
#  ('little', 'JJ'),
#  ('moouse', 'NN'),
#  ('ate', 'VB'),
#  ('the', 'DT'),
#  ('fresh', 'JJ'),
#  ('cheese', 'NN')]

# %%
chunk_result3=chunk_parser2.parse(sent_tokens)
print(chunk_result3)
# Out:
# (S The/DT little/JJ moouse/NN (vp ate/VB) the/DT fresh/JJ cheese/NN)

# %% [markdown]
# We have a tree where "A verb parser where a pronoun followed by two verbs and adverb are chunked together into a verb phase"
